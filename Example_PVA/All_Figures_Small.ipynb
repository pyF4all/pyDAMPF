# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import matplotlib.patches as mpatches
from matplotlib.ticker import FormatStrFormatter

# %%
#READ DATA
direc = os.getcwd()
zc1_1_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom127.dfo", "r"))
zc1_1_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom132.dfo", "r"))
zc1_1_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom137.dfo", "r"))
zc1_1_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom142.dfo", "r"))
zc1_1_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom147.dfo", "r"))
zc1_2_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom148.dfo", "r"))
zc1_2_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom153.dfo", "r"))
zc1_2_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom158.dfo", "r"))
zc1_2_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom163.dfo", "r"))
zc1_2_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom168.dfo", "r"))
zc1_3_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom169.dfo", "r"))
zc1_3_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom174.dfo", "r"))
zc1_3_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom179.dfo", "r"))
zc1_3_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom184.dfo", "r"))
zc1_3_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom189.dfo", "r"))
tc1_1_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom127.dfo", "r"))
tc1_1_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom128.dfo", "r"))
tc1_1_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom129.dfo", "r"))
tc1_1_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom130.dfo", "r"))
tc1_1_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom131.dfo", "r"))
tc1_1_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom132.dfo", "r"))
tc1_1_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom133.dfo", "r"))
tc1_1_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom134.dfo", "r"))
tc1_1_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom135.dfo", "r"))
tc1_1_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom136.dfo", "r"))
tc1_1_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom137.dfo", "r"))
tc1_1_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom138.dfo", "r"))
tc1_1_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom139.dfo", "r"))
tc1_1_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom140.dfo", "r"))
tc1_1_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom141.dfo", "r"))
tc1_1_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom142.dfo", "r"))
tc1_1_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom143.dfo", "r"))
tc1_1_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom144.dfo", "r"))
tc1_1_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom145.dfo", "r"))
tc1_1_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom146.dfo", "r"))
tc1_1_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom147.dfo", "r"))
tc1_2_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom148.dfo", "r"))
tc1_2_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom149.dfo", "r"))
tc1_2_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom150.dfo", "r"))
tc1_2_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom151.dfo", "r"))
tc1_2_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom152.dfo", "r"))
tc1_2_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom153.dfo", "r"))
tc1_2_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom154.dfo", "r"))
tc1_2_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom155.dfo", "r"))
tc1_2_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom156.dfo", "r"))
tc1_2_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom157.dfo", "r"))
tc1_2_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom158.dfo", "r"))
tc1_2_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom159.dfo", "r"))
tc1_2_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom160.dfo", "r"))
tc1_2_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom161.dfo", "r"))
tc1_2_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom162.dfo", "r"))
tc1_2_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom163.dfo", "r"))
tc1_2_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom164.dfo", "r"))
tc1_2_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom165.dfo", "r"))
tc1_2_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom166.dfo", "r"))
tc1_2_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom167.dfo", "r"))
tc1_2_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom168.dfo", "r"))
tc1_3_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom169.dfo", "r"))
tc1_3_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom170.dfo", "r"))
tc1_3_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom171.dfo", "r"))
tc1_3_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom172.dfo", "r"))
tc1_3_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom173.dfo", "r"))
tc1_3_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom174.dfo", "r"))
tc1_3_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom175.dfo", "r"))
tc1_3_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom176.dfo", "r"))
tc1_3_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom177.dfo", "r"))
tc1_3_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom178.dfo", "r"))
tc1_3_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom179.dfo", "r"))
tc1_3_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom180.dfo", "r"))
tc1_3_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom181.dfo", "r"))
tc1_3_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom182.dfo", "r"))
tc1_3_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom183.dfo", "r"))
tc1_3_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom184.dfo", "r"))
tc1_3_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom185.dfo", "r"))
tc1_3_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom186.dfo", "r"))
tc1_3_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom187.dfo", "r"))
tc1_3_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom188.dfo", "r"))
tc1_3_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom189.dfo", "r"))
zc2_1_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom190.dfo", "r"))
zc2_1_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom195.dfo", "r"))
zc2_1_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom200.dfo", "r"))
zc2_1_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom205.dfo", "r"))
zc2_1_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom210.dfo", "r"))
zc2_2_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom211.dfo", "r"))
zc2_2_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom216.dfo", "r"))
zc2_2_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom221.dfo", "r"))
zc2_2_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom226.dfo", "r"))
zc2_2_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom231.dfo", "r"))
zc2_3_65=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom232.dfo", "r"))
zc2_3_70=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom237.dfo", "r"))
zc2_3_75=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom242.dfo", "r"))
zc2_3_80=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom247.dfo", "r"))
zc2_3_85=np.genfromtxt(open(direc+"/ASP65_ASP85/zcdom252.dfo", "r"))
tc2_1_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom190.dfo", "r"))
tc2_1_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom191.dfo", "r"))
tc2_1_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom192.dfo", "r"))
tc2_1_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom193.dfo", "r"))
tc2_1_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom194.dfo", "r"))
tc2_1_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom195.dfo", "r"))
tc2_1_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom196.dfo", "r"))
tc2_1_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom197.dfo", "r"))
tc2_1_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom198.dfo", "r"))
tc2_1_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom199.dfo", "r"))
tc2_1_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom200.dfo", "r"))
tc2_1_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom201.dfo", "r"))
tc2_1_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom202.dfo", "r"))
tc2_1_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom203.dfo", "r"))
tc2_1_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom204.dfo", "r"))
tc2_1_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom205.dfo", "r"))
tc2_1_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom206.dfo", "r"))
tc2_1_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom207.dfo", "r"))
tc2_1_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom208.dfo", "r"))
tc2_1_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom209.dfo", "r"))
tc2_1_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom210.dfo", "r"))
tc2_2_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom211.dfo", "r"))
tc2_2_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom212.dfo", "r"))
tc2_2_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom213.dfo", "r"))
tc2_2_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom214.dfo", "r"))
tc2_2_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom215.dfo", "r"))
tc2_2_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom216.dfo", "r"))
tc2_2_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom217.dfo", "r"))
tc2_2_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom218.dfo", "r"))
tc2_2_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom219.dfo", "r"))
tc2_2_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom220.dfo", "r"))
tc2_2_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom221.dfo", "r"))
tc2_2_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom222.dfo", "r"))
tc2_2_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom223.dfo", "r"))
tc2_2_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom224.dfo", "r"))
tc2_2_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom225.dfo", "r"))
tc2_2_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom226.dfo", "r"))
tc2_2_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom227.dfo", "r"))
tc2_2_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom228.dfo", "r"))
tc2_2_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom229.dfo", "r"))
tc2_2_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom230.dfo", "r"))
tc2_2_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom231.dfo", "r"))
tc2_3_65=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom232.dfo", "r"))
tc2_3_66=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom233.dfo", "r"))
tc2_3_67=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom234.dfo", "r"))
tc2_3_68=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom235.dfo", "r"))
tc2_3_69=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom236.dfo", "r"))
tc2_3_70=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom237.dfo", "r"))
tc2_3_71=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom238.dfo", "r"))
tc2_3_72=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom239.dfo", "r"))
tc2_3_73=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom240.dfo", "r"))
tc2_3_74=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom241.dfo", "r"))
tc2_3_75=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom242.dfo", "r"))
tc2_3_76=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom243.dfo", "r"))
tc2_3_77=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom244.dfo", "r"))
tc2_3_78=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom245.dfo", "r"))
tc2_3_79=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom246.dfo", "r"))
tc2_3_80=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom247.dfo", "r"))
tc2_3_81=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom248.dfo", "r"))
tc2_3_82=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom249.dfo", "r"))
tc2_3_83=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom250.dfo", "r"))
tc2_3_84=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom251.dfo", "r"))
tc2_3_85=np.genfromtxt(open(direc+"/ASP65_ASP85/tdom252.dfo", "r"))

# %%
T2=1/160e3
t=np.linspace(0.1e-6,40000*T2,10000)
Rt=7e-9
Nus=100
Es1c1=577.87e6
Es2c1=475.09e6
Es3c1=195.20e6
Es1c2=429.21e6
Es2c2=398.36e6
Es3c2=377.69e6
Es=([Es1c1,Es2c1,Es3c1,Es1c2,Es2c2,Es3c2])
Aspf=8.0
Asp65=6.5
Asp70=7.0
Asp75=7.5
Asp80=8.0
Asp85=8.5
Asp=np.array([Asp65,Asp70,Asp75,Asp80,Asp85])
Asp1 = [6.500,6.600,6.700,6.800,6.900,7.000,7.100,7.200,7.300,7.400,7.500,7.600,7.700,7.800,7.900, 8.000,8.100,8.200,8.300,8.400,8.500]
Aspn1 = [0.65,0.66,0.67,0.68,0.69,0.7,0.71,0.72,0.73,0.74,0.75,0.76,0.77,0.78,0.79,0.8,0.81,0.82,0.83,0.84,0.85]
RH = ['$RH_1$','$RH_2$','$RH_3$']
def FsFd (zcdom,Es,Asp):
    aux1 = np.where(zcdom[:, 1] == zcdom[:, 1].flat[np.abs(zcdom[:, 1] - Asp).argmin()])
    aux3= 0.165 -(zcdom[:, 3][aux1])     #DMIN
    aux4= (zcdom[:, 2][aux1])            #FASE
    coef=np.sqrt(Rt)*np.sqrt(np.abs((aux3)*1.e-9)) 
    Fsto=coef*(1.25*Es)*((aux3)*1.e-9)*np.cos(2.*np.pi*160e3*t)
    Fdis=coef*(Nus)*(Asp*1.e-9*2.*np.pi*160e3*np.sin(2.*np.pi*160e3*t-(aux4)*np.pi/180))#/(np.sin(2*np.pi*tcp4[i]*(1/freq[i])*t))
    Fpro=Fsto+Fdis
    return (Fsto*1e9,Fdis*1e9,Fpro*1e9)

# %%
FmaxHR1 = [np.min(tc1_1_65[:, 4]),np.min(tc1_1_66[:, 4]),np.min(tc1_1_67[:, 4]),np.min(tc1_1_68[:, 4])
            ,np.min(tc1_1_69[:, 4]),np.min(tc1_1_70[:, 4]),np.min(tc1_1_71[:, 4]),np.min(tc1_1_72[:, 4])
            ,np.min(tc1_1_73[:, 4]),np.min(tc1_1_74[:, 4]),np.min(tc1_1_75[:, 4]),np.min(tc1_1_76[:, 4])
            ,np.min(tc1_1_77[:, 4]),np.min(tc1_1_78[:, 4]),np.min(tc1_1_79[:, 4]),np.min(tc1_1_80[:, 4])
            ,np.min(tc1_1_81[:, 4]),np.min(tc1_1_82[:, 4]),np.min(tc1_1_83[:, 4]),np.min(tc1_1_84[:, 4])
            ,np.min(tc1_1_85[:, 4])]
FmaxHR2 = [np.min(tc1_2_65[:, 4]),np.min(tc1_2_66[:, 4]),np.min(tc1_2_67[:, 4]),np.min(tc1_2_68[:, 4])
            ,np.min(tc1_2_69[:, 4]),np.min(tc1_2_70[:, 4]),np.min(tc1_2_71[:, 4]),np.min(tc1_2_72[:, 4])
            ,np.min(tc1_2_73[:, 4]),np.min(tc1_2_74[:, 4]),np.min(tc1_2_75[:, 4]),np.min(tc1_2_76[:, 4])
            ,np.min(tc1_2_77[:, 4]),np.min(tc1_2_78[:, 4]),np.min(tc1_2_79[:, 4]),np.min(tc1_2_80[:, 4])
            ,np.min(tc1_2_81[:, 4]),np.min(tc1_2_82[:, 4]),np.min(tc1_2_83[:, 4]),np.min(tc1_2_84[:, 4])
            ,np.min(tc1_2_85[:, 4])]
FmaxHR3 = [np.min(tc1_3_65[:, 4]),np.min(tc1_3_66[:, 4]),np.min(tc1_3_67[:, 4]),np.min(tc1_3_68[:, 4])
            ,np.min(tc1_3_69[:, 4]),np.min(tc1_3_70[:, 4]),np.min(tc1_3_71[:, 4]),np.min(tc1_3_72[:, 4])
            ,np.min(tc1_3_73[:, 4]),np.min(tc1_3_74[:, 4]),np.min(tc1_3_75[:, 4]),np.min(tc1_3_76[:, 4])
            ,np.min(tc1_3_77[:, 4]),np.min(tc1_3_78[:, 4]),np.min(tc1_3_79[:, 4]),np.min(tc1_3_80[:, 4])
            ,np.min(tc1_3_81[:, 4]),np.min(tc1_3_82[:, 4]),np.min(tc1_3_83[:, 4]),np.min(tc1_3_84[:, 4])
            ,np.min(tc1_3_85[:, 4])]
print()
print('FOR RH1')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR1), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR1.index(np.min(FmaxHR1))])
print()
print('FOR RH2')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR2), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR2.index(np.min(FmaxHR2))])
print()
print('FOR RH3')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR3), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR3.index(np.min(FmaxHR3))])
# Out:
# FOR RH1
# HIGHER DISSIPATIVE FORCE:  -0.61027 WHERE A_sp/A_o is:  0.83
#
# FOR RH2
# HIGHER DISSIPATIVE FORCE:  -0.64404 WHERE A_sp/A_o is:  0.82
#
# FOR RH3
# HIGHER DISSIPATIVE FORCE:  -0.83523 WHERE A_sp/A_o is:  0.77

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_1_66[:, 0], tc1_1_66[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_67[:, 0], tc1_1_67[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_68[:, 0], tc1_1_68[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_69[:, 0], tc1_1_69[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_70[:, 0], tc1_1_70[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_71[:, 0], tc1_1_71[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_72[:, 0], tc1_1_72[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_73[:, 0], tc1_1_73[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_74[:, 0], tc1_1_74[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_75[:, 0], tc1_1_75[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_76[:, 0], tc1_1_76[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_77[:, 0], tc1_1_77[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_78[:, 0], tc1_1_78[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_79[:, 0], tc1_1_79[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_81[:, 0], tc1_1_81[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_82[:, 0], tc1_1_82[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_84[:, 0], tc1_1_84[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc1_1_65[:, 0], tc1_1_65[:, 4], color='black', ls = '--', label='$A_{sp}/A_0=0.65$', linewidth=3.0)
plt.plot(tc1_1_83[:, 0], tc1_1_83[:, 4],color='#9E9E9E', ls = '--',label='$A_{sp}/A_0=0.83$', linewidth=3.0)
plt.plot(tc1_1_85[:, 0], tc1_1_85[:, 4], color='darkred', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.text(999.52, 1.3, '$RH_1$', fontsize=20, color='red')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR1C2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_2_66[:, 0], tc1_2_66[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_67[:, 0], tc1_2_67[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_68[:, 0], tc1_2_68[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_69[:, 0], tc1_2_69[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_70[:, 0], tc1_2_70[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_71[:, 0], tc1_2_71[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_72[:, 0], tc1_2_72[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_73[:, 0], tc1_2_73[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_74[:, 0], tc1_2_74[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_75[:, 0], tc1_2_75[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_76[:, 0], tc1_2_76[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_77[:, 0], tc1_2_77[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_78[:, 0], tc1_2_78[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_79[:, 0], tc1_2_79[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_81[:, 0], tc1_2_81[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_83[:, 0], tc1_2_83[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_84[:, 0], tc1_2_84[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc1_2_65[:, 0], tc1_2_65[:, 4], color='black', ls = '--', label='$A_{sp}/A_0=0.65$', linewidth=3.0)
plt.plot(tc1_2_82[:, 0], tc1_2_82[:, 4], color='#9E9E9E', ls = '--',label='$A_{sp}/A_0=0.82$', linewidth=3.0)
plt.plot(tc1_2_85[:, 0], tc1_2_85[:, 4], color='purple', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.text(999.52, 1.2, '$RH_2$', fontsize=20, color='#DA55D3')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR2C2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_3_66[:, 0], tc1_3_66[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_67[:, 0], tc1_3_67[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_68[:, 0], tc1_3_68[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_69[:, 0], tc1_3_69[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_70[:, 0], tc1_3_70[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_71[:, 0], tc1_3_71[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_72[:, 0], tc1_3_72[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_73[:, 0], tc1_3_73[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_74[:, 0], tc1_3_74[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_75[:, 0], tc1_3_75[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_76[:, 0], tc1_3_76[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_78[:, 0], tc1_3_78[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_79[:, 0], tc1_3_79[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_81[:, 0], tc1_3_81[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_82[:, 0], tc1_3_82[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_83[:, 0], tc1_3_83[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_84[:, 0], tc1_3_84[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc1_3_65[:, 0], tc1_3_65[:, 4], color='black', ls = '--', linewidth=3.0, label='$A_{sp}/A_0=0.65$')
plt.plot(tc1_3_77[:, 0], tc1_3_77[:, 4], color='#757575', ls = '--',label='$A_{sp}/A_0=0.77$', linewidth=3.0)
plt.plot(tc1_3_85[:, 0], tc1_3_85[:, 4], color='darkblue', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.text(999.52, 0.95, '$RH_3$', fontsize=20, color='blue')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR3C2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
FmaxHR1 = [np.min(tc2_1_65[:, 4]),np.min(tc2_1_66[:, 4]),np.min(tc2_1_67[:, 4]),np.min(tc2_1_68[:, 4])
            ,np.min(tc2_1_69[:, 4]),np.min(tc2_1_70[:, 4]),np.min(tc2_1_71[:, 4]),np.min(tc2_1_72[:, 4])
            ,np.min(tc2_1_73[:, 4]),np.min(tc2_1_74[:, 4]),np.min(tc2_1_75[:, 4]),np.min(tc2_1_76[:, 4])
            ,np.min(tc2_1_77[:, 4]),np.min(tc2_1_78[:, 4]),np.min(tc2_1_79[:, 4]),np.min(tc2_1_80[:, 4])
            ,np.min(tc2_1_81[:, 4]),np.min(tc2_1_82[:, 4]),np.min(tc2_1_83[:, 4]),np.min(tc2_1_84[:, 4])
            ,np.min(tc2_1_85[:, 4])]
FmaxHR2 = [np.min(tc2_2_65[:, 4]),np.min(tc2_2_66[:, 4]),np.min(tc2_2_67[:, 4]),np.min(tc2_2_68[:, 4])
            ,np.min(tc2_2_69[:, 4]),np.min(tc2_2_70[:, 4]),np.min(tc2_2_71[:, 4]),np.min(tc2_2_72[:, 4])
            ,np.min(tc2_2_73[:, 4]),np.min(tc2_2_74[:, 4]),np.min(tc2_2_75[:, 4]),np.min(tc2_2_76[:, 4])
            ,np.min(tc2_2_77[:, 4]),np.min(tc2_2_78[:, 4]),np.min(tc2_2_79[:, 4]),np.min(tc2_2_80[:, 4])
            ,np.min(tc2_2_81[:, 4]),np.min(tc2_2_82[:, 4]),np.min(tc2_2_83[:, 4]),np.min(tc2_2_84[:, 4])
            ,np.min(tc2_2_85[:, 4])]
FmaxHR3 = [np.min(tc2_3_65[:, 4]),np.min(tc2_3_66[:, 4]),np.min(tc2_3_67[:, 4]),np.min(tc2_3_68[:, 4])
            ,np.min(tc2_3_69[:, 4]),np.min(tc2_3_70[:, 4]),np.min(tc2_3_71[:, 4]),np.min(tc2_3_72[:, 4])
            ,np.min(tc2_3_73[:, 4]),np.min(tc2_3_74[:, 4]),np.min(tc2_3_75[:, 4]),np.min(tc2_3_76[:, 4])
            ,np.min(tc2_3_77[:, 4]),np.min(tc2_3_78[:, 4]),np.min(tc2_3_79[:, 4]),np.min(tc2_3_80[:, 4])
            ,np.min(tc2_3_81[:, 4]),np.min(tc2_3_82[:, 4]),np.min(tc2_3_83[:, 4]),np.min(tc2_3_84[:, 4])
            ,np.min(tc2_3_85[:, 4])]

print()
print('FOR RH1')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR1), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR1.index(np.min(FmaxHR1))])
print()
print('FOR RH2')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR2), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR2.index(np.min(FmaxHR2))])
print()
print('FOR RH3')
print('HIGHER DISSIPATIVE FORCE: ',np.min(FmaxHR3), 'WHERE A_sp/A_o is: ', Aspn1[FmaxHR3.index(np.min(FmaxHR3))])
# Out:
# FOR RH1
# HIGHER DISSIPATIVE FORCE:  -0.66361 WHERE A_sp/A_o is:  0.82
#
# FOR RH2
# HIGHER DISSIPATIVE FORCE:  -0.67758 WHERE A_sp/A_o is:  0.83
#
# FOR RH3
# HIGHER DISSIPATIVE FORCE:  -0.68759 WHERE A_sp/A_o is:  0.82

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc2_1_66[:, 0], tc2_1_66[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_67[:, 0], tc2_1_67[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_68[:, 0], tc2_1_68[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_69[:, 0], tc2_1_69[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_70[:, 0], tc2_1_70[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_71[:, 0], tc2_1_71[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_72[:, 0], tc2_1_72[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_73[:, 0], tc2_1_73[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_74[:, 0], tc2_1_74[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_75[:, 0], tc2_1_75[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_76[:, 0], tc2_1_76[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_77[:, 0], tc2_1_77[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_78[:, 0], tc2_1_78[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_79[:, 0], tc2_1_79[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_80[:, 0], tc2_1_80[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_81[:, 0], tc2_1_81[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_83[:, 0], tc2_1_83[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_84[:, 0], tc2_1_84[:, 4], color='red', ls = '--',alpha=0.5)
plt.plot(tc2_1_65[:, 0], tc2_1_65[:, 4], color='black', ls = '--', label='$A_{sp}/A_0=0.65$', linewidth=3.0)
plt.plot(tc2_1_82[:, 0], tc2_1_82[:, 4], color='#9E9E9E', ls = '--',label='$A_{sp}/A_0=0.82$', linewidth=3.0)
plt.plot(tc2_1_85[:, 0], tc2_1_85[:, 4], color='darkred', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.text(999.52, 1.2, '$RH_1$', fontsize=20, color='red')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR1C1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc2_2_66[:, 0], tc2_2_66[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_67[:, 0], tc2_2_67[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_68[:, 0], tc2_2_68[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_69[:, 0], tc2_2_69[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_70[:, 0], tc2_2_70[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_71[:, 0], tc2_2_71[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_72[:, 0], tc2_2_72[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_73[:, 0], tc2_2_73[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_74[:, 0], tc2_2_74[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_75[:, 0], tc2_2_75[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_76[:, 0], tc2_2_76[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_77[:, 0], tc2_2_77[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_78[:, 0], tc2_2_78[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_79[:, 0], tc2_2_79[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_80[:, 0], tc2_2_80[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_81[:, 0], tc2_2_81[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_82[:, 0], tc2_2_82[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_84[:, 0], tc2_2_84[:, 4], color='orchid', ls = '--',alpha=0.5)
plt.plot(tc2_2_65[:, 0], tc2_2_65[:, 4], color='black', ls = '--', label='$A_{sp}/A_0=0.65$', linewidth=3.0)
plt.plot(tc2_2_83[:, 0], tc2_2_83[:, 4], color='#9E9E9E', ls = '--',label='$A_{sp}/A_0=0.83$', linewidth=3.0)
plt.plot(tc2_2_85[:, 0], tc2_2_85[:, 4], color='purple', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.text(999.52, 1.15, '$RH_2$', fontsize=20, color='#DA55D3')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR2C1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 15}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc2_3_66[:, 0], tc2_3_66[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_67[:, 0], tc2_3_67[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_68[:, 0], tc2_3_68[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_69[:, 0], tc2_3_69[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_70[:, 0], tc2_3_70[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_71[:, 0], tc2_3_71[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_72[:, 0], tc2_3_72[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_73[:, 0], tc2_3_73[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_74[:, 0], tc2_3_74[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_75[:, 0], tc2_3_75[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_76[:, 0], tc2_3_76[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_77[:, 0], tc2_3_77[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_78[:, 0], tc2_3_78[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_79[:, 0], tc2_3_79[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_80[:, 0], tc2_3_80[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_81[:, 0], tc2_3_81[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_83[:, 0], tc2_3_83[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_84[:, 0], tc2_3_84[:, 4], color='blue', ls = '--',alpha=0.5)
plt.plot(tc2_3_65[:, 0], tc2_3_65[:, 4], color='black', ls = '--', linewidth=3.0, label='$A_{sp}/A_0=0.65$')
plt.plot(tc2_3_82[:, 0], tc2_3_82[:, 4], color='#757575', ls = '--',label='$A_{sp}/A_0=0.82$', linewidth=3.0)
plt.plot(tc2_3_85[:, 0], tc2_3_85[:, 4], color='darkblue', ls = '--', label='$A_{sp}/A_0=0.85$', linewidth=3.0)
plt.text(999.52, 1.15, '$RH_3$', fontsize=20, color='blue')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(loc='upper right')
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/figAspHR3C1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Peak$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.max(tc1_1_65[:, 4]),np.max(tc1_1_66[:, 4]),np.max(tc1_1_67[:, 4]),np.max(tc1_1_68[:, 4])
            ,np.max(tc1_1_69[:, 4]),np.max(tc1_1_70[:, 4]),np.max(tc1_1_71[:, 4]),np.max(tc1_1_72[:, 4])
            ,np.max(tc1_1_73[:, 4]),np.max(tc1_1_74[:, 4]),np.max(tc1_1_75[:, 4]),np.max(tc1_1_76[:, 4])
            ,np.max(tc1_1_77[:, 4]),np.max(tc1_1_78[:, 4]),np.max(tc1_1_79[:, 4]),np.max(tc1_1_80[:, 4])
            ,np.max(tc1_1_81[:, 4]),np.max(tc1_1_82[:, 4]),np.max(tc1_1_83[:, 4]),np.max(tc1_1_84[:, 4])
            ,np.max(tc1_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.max(tc1_2_65[:, 4]),np.max(tc1_2_66[:, 4]),np.max(tc1_2_67[:, 4]),np.max(tc1_2_68[:, 4])
            ,np.max(tc1_2_69[:, 4]),np.max(tc1_2_70[:, 4]),np.max(tc1_2_71[:, 4]),np.max(tc1_2_72[:, 4])
            ,np.max(tc1_2_73[:, 4]),np.max(tc1_2_74[:, 4]),np.max(tc1_2_75[:, 4]),np.max(tc1_2_76[:, 4])
            ,np.max(tc1_2_77[:, 4]),np.max(tc1_2_78[:, 4]),np.max(tc1_2_79[:, 4]),np.max(tc1_2_80[:, 4])
            ,np.max(tc1_2_81[:, 4]),np.max(tc1_2_82[:, 4]),np.max(tc1_2_83[:, 4]),np.max(tc1_2_84[:, 4])
            ,np.max(tc1_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
FmaxHR3 = [np.max(tc1_3_65[:, 4]),np.max(tc1_3_66[:, 4]),np.max(tc1_3_67[:, 4]),np.max(tc1_3_68[:, 4])
            ,np.max(tc1_3_69[:, 4]),np.max(tc1_3_70[:, 4]),np.max(tc1_3_71[:, 4]),np.max(tc1_3_72[:, 4])
            ,np.max(tc1_3_73[:, 4]),np.max(tc1_3_74[:, 4]),np.max(tc1_3_75[:, 4]),np.max(tc1_3_76[:, 4])
            ,np.max(tc1_3_77[:, 4]),np.max(tc1_3_78[:, 4]),np.max(tc1_3_79[:, 4]),np.max(tc1_3_80[:, 4])
            ,np.max(tc1_3_81[:, 4]),np.max(tc1_3_82[:, 4]),np.max(tc1_3_83[:, 4]),np.max(tc1_3_84[:, 4])
            ,np.max(tc1_3_85[:, 4])]
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/PeakF_c2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Peak$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.max(tc2_1_65[:, 4]),np.max(tc2_1_66[:, 4]),np.max(tc2_1_67[:, 4]),np.max(tc2_1_68[:, 4])
            ,np.max(tc2_1_69[:, 4]),np.max(tc2_1_70[:, 4]),np.max(tc2_1_71[:, 4]),np.max(tc2_1_72[:, 4])
            ,np.max(tc2_1_73[:, 4]),np.max(tc2_1_74[:, 4]),np.max(tc2_1_75[:, 4]),np.max(tc2_1_76[:, 4])
            ,np.max(tc2_1_77[:, 4]),np.max(tc2_1_78[:, 4]),np.max(tc2_1_79[:, 4]),np.max(tc2_1_80[:, 4])
            ,np.max(tc2_1_81[:, 4]),np.max(tc2_1_82[:, 4]),np.max(tc2_1_83[:, 4]),np.max(tc2_1_84[:, 4])
            ,np.max(tc2_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.max(tc2_2_65[:, 4]),np.max(tc2_2_66[:, 4]),np.max(tc2_2_67[:, 4]),np.max(tc2_2_68[:, 4])
            ,np.max(tc2_2_69[:, 4]),np.max(tc2_2_70[:, 4]),np.max(tc2_2_71[:, 4]),np.max(tc2_2_72[:, 4])
            ,np.max(tc2_2_73[:, 4]),np.max(tc2_2_74[:, 4]),np.max(tc2_2_75[:, 4]),np.max(tc2_2_76[:, 4])
            ,np.max(tc2_2_77[:, 4]),np.max(tc2_2_78[:, 4]),np.max(tc2_2_79[:, 4]),np.max(tc2_2_80[:, 4])
            ,np.max(tc2_2_81[:, 4]),np.max(tc2_2_82[:, 4]),np.max(tc2_2_83[:, 4]),np.max(tc2_2_84[:, 4])
            ,np.max(tc2_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
FmaxHR3 = [np.max(tc2_3_65[:, 4]),np.max(tc2_3_66[:, 4]),np.max(tc2_3_67[:, 4]),np.max(tc2_3_68[:, 4])
            ,np.max(tc2_3_69[:, 4]),np.max(tc2_3_70[:, 4]),np.max(tc2_3_71[:, 4]),np.max(tc2_3_72[:, 4])
            ,np.max(tc2_3_73[:, 4]),np.max(tc2_3_74[:, 4]),np.max(tc2_3_75[:, 4]),np.max(tc2_3_76[:, 4])
            ,np.max(tc2_3_77[:, 4]),np.max(tc2_3_78[:, 4]),np.max(tc2_3_79[:, 4]),np.max(tc2_3_80[:, 4])
            ,np.max(tc2_3_81[:, 4]),np.max(tc2_3_82[:, 4]),np.max(tc2_3_83[:, 4]),np.max(tc2_3_84[:, 4])
            ,np.max(tc2_3_85[:, 4])]
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/PeakF_c1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Peak_{dis}$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.min(tc1_1_65[:, 4]),np.min(tc1_1_66[:, 4]),np.min(tc1_1_67[:, 4]),np.min(tc1_1_68[:, 4])
            ,np.min(tc1_1_69[:, 4]),np.min(tc1_1_70[:, 4]),np.min(tc1_1_71[:, 4]),np.min(tc1_1_72[:, 4])
            ,np.min(tc1_1_73[:, 4]),np.min(tc1_1_74[:, 4]),np.min(tc1_1_75[:, 4]),np.min(tc1_1_76[:, 4])
            ,np.min(tc1_1_77[:, 4]),np.min(tc1_1_78[:, 4]),np.min(tc1_1_79[:, 4]),np.min(tc1_1_80[:, 4])
            ,np.min(tc1_1_81[:, 4]),np.min(tc1_1_82[:, 4]),np.min(tc1_1_83[:, 4]),np.min(tc1_1_84[:, 4])
            ,np.min(tc1_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.min(tc1_2_65[:, 4]),np.min(tc1_2_66[:, 4]),np.min(tc1_2_67[:, 4]),np.min(tc1_2_68[:, 4])
            ,np.min(tc1_2_69[:, 4]),np.min(tc1_2_70[:, 4]),np.min(tc1_2_71[:, 4]),np.min(tc1_2_72[:, 4])
            ,np.min(tc1_2_73[:, 4]),np.min(tc1_2_74[:, 4]),np.min(tc1_2_75[:, 4]),np.min(tc1_2_76[:, 4])
            ,np.min(tc1_2_77[:, 4]),np.min(tc1_2_78[:, 4]),np.min(tc1_2_79[:, 4]),np.min(tc1_2_80[:, 4])
            ,np.min(tc1_2_81[:, 4]),np.min(tc1_2_82[:, 4]),np.min(tc1_2_83[:, 4]),np.min(tc1_2_84[:, 4])
            ,np.min(tc1_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
FmaxHR3 = [np.min(tc1_3_65[:, 4]),np.min(tc1_3_66[:, 4]),np.min(tc1_3_67[:, 4]),np.min(tc1_3_68[:, 4])
            ,np.min(tc1_3_69[:, 4]),np.min(tc1_3_70[:, 4]),np.min(tc1_3_71[:, 4]),np.min(tc1_3_72[:, 4])
            ,np.min(tc1_3_73[:, 4]),np.min(tc1_3_74[:, 4]),np.min(tc1_3_75[:, 4]),np.min(tc1_3_76[:, 4])
            ,np.min(tc1_3_77[:, 4]),np.min(tc1_3_78[:, 4]),np.min(tc1_3_79[:, 4]),np.min(tc1_3_80[:, 4])
            ,np.min(tc1_3_81[:, 4]),np.min(tc1_3_82[:, 4]),np.min(tc1_3_83[:, 4]),np.min(tc1_3_84[:, 4])
            ,np.min(tc1_3_85[:, 4])]
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.ylim(-0.88,-0.57)
plt.savefig('Figures/PeakF_dis_c2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Peak_{dis}$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.min(tc2_1_65[:, 4]),np.min(tc2_1_66[:, 4]),np.min(tc2_1_67[:, 4]),np.min(tc2_1_68[:, 4])
            ,np.min(tc2_1_69[:, 4]),np.min(tc2_1_70[:, 4]),np.min(tc2_1_71[:, 4]),np.min(tc2_1_72[:, 4])
            ,np.min(tc2_1_73[:, 4]),np.min(tc2_1_74[:, 4]),np.min(tc2_1_75[:, 4]),np.min(tc2_1_76[:, 4])
            ,np.min(tc2_1_77[:, 4]),np.min(tc2_1_78[:, 4]),np.min(tc2_1_79[:, 4]),np.min(tc2_1_80[:, 4])
            ,np.min(tc2_1_81[:, 4]),np.min(tc2_1_82[:, 4]),np.min(tc2_1_83[:, 4]),np.min(tc2_1_84[:, 4])
            ,np.min(tc2_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.min(tc2_2_65[:, 4]),np.min(tc2_2_66[:, 4]),np.min(tc2_2_67[:, 4]),np.min(tc2_2_68[:, 4])
            ,np.min(tc2_2_69[:, 4]),np.min(tc2_2_70[:, 4]),np.min(tc2_2_71[:, 4]),np.min(tc2_2_72[:, 4])
            ,np.min(tc2_2_73[:, 4]),np.min(tc2_2_74[:, 4]),np.min(tc2_2_75[:, 4]),np.min(tc2_2_76[:, 4])
            ,np.min(tc2_2_77[:, 4]),np.min(tc2_2_78[:, 4]),np.min(tc2_2_79[:, 4]),np.min(tc2_2_80[:, 4])
            ,np.min(tc2_2_81[:, 4]),np.min(tc2_2_82[:, 4]),np.min(tc2_2_83[:, 4]),np.min(tc2_2_84[:, 4])
            ,np.min(tc2_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
# hr3
FmaxHR3 = [np.min(tc2_3_65[:, 4]),np.min(tc2_3_66[:, 4]),np.min(tc2_3_67[:, 4]),np.min(tc2_3_68[:, 4])
            ,np.min(tc2_3_69[:, 4]),np.min(tc2_3_70[:, 4]),np.min(tc2_3_71[:, 4]),np.min(tc2_3_72[:, 4])
            ,np.min(tc2_3_73[:, 4]),np.min(tc2_3_74[:, 4]),np.min(tc2_3_75[:, 4]),np.min(tc2_3_76[:, 4])
            ,np.min(tc2_3_77[:, 4]),np.min(tc2_3_78[:, 4]),np.min(tc2_3_79[:, 4]),np.min(tc2_3_80[:, 4])
            ,np.min(tc2_3_81[:, 4]),np.min(tc2_3_82[:, 4]),np.min(tc2_3_83[:, 4]),np.min(tc2_3_84[:, 4])
            ,np.min(tc2_3_85[:, 4])]
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.ylim(-0.69,-0.635)
plt.savefig('Figures/PeakF_dis_c1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$\Delta \: Peak$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.max(tc1_1_65[:, 4])+np.min(tc1_1_65[:, 4]),np.max(tc1_1_66[:, 4])+np.min(tc1_1_66[:, 4]),np.max(tc1_1_67[:, 4])+np.min(tc1_1_67[:, 4]),np.max(tc1_1_68[:, 4])+np.min(tc1_1_68[:, 4])
            ,np.max(tc1_1_69[:, 4])+np.min(tc1_1_69[:, 4]),np.max(tc1_1_70[:, 4])+np.min(tc1_1_70[:, 4]),np.max(tc1_1_71[:, 4])+np.min(tc1_1_71[:, 4]),np.max(tc1_1_72[:, 4])+np.min(tc1_1_72[:, 4])
            ,np.max(tc1_1_73[:, 4])+np.min(tc1_1_73[:, 4]),np.max(tc1_1_74[:, 4])+np.min(tc1_1_74[:, 4]),np.max(tc1_1_75[:, 4])+np.min(tc1_1_75[:, 4]),np.max(tc1_1_76[:, 4])+np.min(tc1_1_76[:, 4])
            ,np.max(tc1_1_77[:, 4])+np.min(tc1_1_77[:, 4]),np.max(tc1_1_78[:, 4])+np.min(tc1_1_78[:, 4]),np.max(tc1_1_79[:, 4])+np.min(tc1_1_79[:, 4]),np.max(tc1_1_80[:, 4])+np.min(tc1_1_80[:, 4])
            ,np.max(tc1_1_81[:, 4])+np.min(tc1_1_81[:, 4]),np.max(tc1_1_82[:, 4])+np.min(tc1_1_82[:, 4]),np.max(tc1_1_83[:, 4])+np.min(tc1_1_83[:, 4]),np.max(tc1_1_84[:, 4])+np.min(tc1_1_84[:, 4])
            ,np.max(tc1_1_85[:, 4])+np.min(tc1_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.max(tc1_2_65[:, 4])+np.min(tc1_2_65[:, 4]),np.max(tc1_2_66[:, 4])+np.min(tc1_2_66[:, 4]),np.max(tc1_2_67[:, 4])+np.min(tc1_2_67[:, 4]),np.max(tc1_2_68[:, 4])+np.min(tc1_2_68[:, 4])
            ,np.max(tc1_2_69[:, 4])+np.min(tc1_2_69[:, 4]),np.max(tc1_2_70[:, 4])+np.min(tc1_2_70[:, 4]),np.max(tc1_2_71[:, 4])+np.min(tc1_2_71[:, 4]),np.max(tc1_2_72[:, 4])+np.min(tc1_2_72[:, 4])
            ,np.max(tc1_2_73[:, 4])+np.min(tc1_2_73[:, 4]),np.max(tc1_2_74[:, 4])+np.min(tc1_2_74[:, 4]),np.max(tc1_2_75[:, 4])+np.min(tc1_2_75[:, 4]),np.max(tc1_2_76[:, 4])+np.min(tc1_2_76[:, 4])
            ,np.max(tc1_2_77[:, 4])+np.min(tc1_2_77[:, 4]),np.max(tc1_2_78[:, 4])+np.min(tc1_2_78[:, 4]),np.max(tc1_2_79[:, 4])+np.min(tc1_2_79[:, 4]),np.max(tc1_2_80[:, 4])+np.min(tc1_2_80[:, 4])
            ,np.max(tc1_2_81[:, 4])+np.min(tc1_2_81[:, 4]),np.max(tc1_2_82[:, 4])+np.min(tc1_2_82[:, 4]),np.max(tc1_2_83[:, 4])+np.min(tc1_2_83[:, 4]),np.max(tc1_2_84[:, 4])+np.min(tc1_2_84[:, 4])
            ,np.max(tc1_2_85[:, 4])+np.min(tc1_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
FmaxHR3 = [np.max(tc1_3_65[:, 4])+np.min(tc1_3_65[:, 4]),np.max(tc1_3_66[:, 4])+np.min(tc1_3_66[:, 4]),np.max(tc1_3_67[:, 4])+np.min(tc1_3_67[:, 4]),np.max(tc1_3_68[:, 4])+np.min(tc1_3_68[:, 4])
            ,np.max(tc1_3_69[:, 4])+np.min(tc1_3_69[:, 4]),np.max(tc1_3_70[:, 4])+np.min(tc1_3_70[:, 4]),np.max(tc1_3_71[:, 4])+np.min(tc1_3_71[:, 4]),np.max(tc1_3_72[:, 4])+np.min(tc1_3_72[:, 4])
            ,np.max(tc1_3_73[:, 4])+np.min(tc1_3_73[:, 4]),np.max(tc1_3_74[:, 4])+np.min(tc1_3_74[:, 4]),np.max(tc1_3_75[:, 4])+np.min(tc1_3_75[:, 4]),np.max(tc1_3_76[:, 4])+np.min(tc1_3_76[:, 4])
            ,np.max(tc1_3_77[:, 4])+np.min(tc1_3_77[:, 4]),np.max(tc1_3_78[:, 4])+np.min(tc1_3_78[:, 4]),np.max(tc1_3_79[:, 4])+np.min(tc1_3_79[:, 4]),np.max(tc1_3_80[:, 4])+np.min(tc1_3_80[:, 4])
            ,np.max(tc1_3_81[:, 4])+np.min(tc1_3_81[:, 4]),np.max(tc1_3_82[:, 4])+np.min(tc1_3_82[:, 4]),np.max(tc1_3_83[:, 4])+np.min(tc1_3_83[:, 4]),np.max(tc1_3_84[:, 4])+np.min(tc1_3_84[:, 4])
            ,np.max(tc1_3_85[:, 4])+np.min(tc1_3_85[:, 4])]
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/delta_PickF_c2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$\Delta \: Peak$ $Force [nN]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
FmaxHR1 = [np.max(tc2_1_65[:, 4])+np.min(tc2_1_65[:, 4]),np.max(tc2_1_66[:, 4])+np.min(tc2_1_66[:, 4]),np.max(tc2_1_67[:, 4])+np.min(tc2_1_67[:, 4]),np.max(tc2_1_68[:, 4])+np.min(tc2_1_68[:, 4])
            ,np.max(tc2_1_69[:, 4])+np.min(tc2_1_69[:, 4]),np.max(tc2_1_70[:, 4])+np.min(tc2_1_70[:, 4]),np.max(tc2_1_71[:, 4])+np.min(tc2_1_71[:, 4]),np.max(tc2_1_72[:, 4])+np.min(tc2_1_72[:, 4])
            ,np.max(tc2_1_73[:, 4])+np.min(tc2_1_73[:, 4]),np.max(tc2_1_74[:, 4])+np.min(tc2_1_74[:, 4]),np.max(tc2_1_75[:, 4])+np.min(tc2_1_75[:, 4]),np.max(tc2_1_76[:, 4])+np.min(tc2_1_76[:, 4])
            ,np.max(tc2_1_77[:, 4])+np.min(tc2_1_77[:, 4]),np.max(tc2_1_78[:, 4])+np.min(tc2_1_78[:, 4]),np.max(tc2_1_79[:, 4])+np.min(tc2_1_79[:, 4]),np.max(tc2_1_80[:, 4])+np.min(tc2_1_80[:, 4])
            ,np.max(tc2_1_81[:, 4])+np.min(tc2_1_81[:, 4]),np.max(tc2_1_82[:, 4])+np.min(tc2_1_82[:, 4]),np.max(tc2_1_83[:, 4])+np.min(tc2_1_83[:, 4]),np.max(tc2_1_84[:, 4])+np.min(tc2_1_84[:, 4])
            ,np.max(tc2_1_85[:, 4])+np.min(tc2_1_85[:, 4])]
plt.plot(Aspn1, FmaxHR1, 'o-', label=RH[0], color='red')
FmaxHR2 = [np.max(tc2_2_65[:, 4])+np.min(tc2_2_65[:, 4]),np.max(tc2_2_66[:, 4])+np.min(tc2_2_66[:, 4]),np.max(tc2_2_67[:, 4])+np.min(tc2_2_67[:, 4]),np.max(tc2_2_68[:, 4])+np.min(tc2_2_68[:, 4])
            ,np.max(tc2_2_69[:, 4])+np.min(tc2_2_69[:, 4]),np.max(tc2_2_70[:, 4])+np.min(tc2_2_70[:, 4]),np.max(tc2_2_71[:, 4])+np.min(tc2_2_71[:, 4]),np.max(tc2_2_72[:, 4])+np.min(tc2_2_72[:, 4])
            ,np.max(tc2_2_73[:, 4])+np.min(tc2_2_73[:, 4]),np.max(tc2_2_74[:, 4])+np.min(tc2_2_74[:, 4]),np.max(tc2_2_75[:, 4])+np.min(tc2_2_75[:, 4]),np.max(tc2_2_76[:, 4])+np.min(tc2_2_76[:, 4])
            ,np.max(tc2_2_77[:, 4])+np.min(tc2_2_77[:, 4]),np.max(tc2_2_78[:, 4])+np.min(tc2_2_78[:, 4]),np.max(tc2_2_79[:, 4])+np.min(tc2_2_79[:, 4]),np.max(tc2_2_80[:, 4])+np.min(tc2_2_80[:, 4])
            ,np.max(tc2_2_81[:, 4])+np.min(tc2_2_81[:, 4]),np.max(tc2_2_82[:, 4])+np.min(tc2_2_82[:, 4]),np.max(tc2_2_83[:, 4])+np.min(tc2_2_83[:, 4]),np.max(tc2_2_84[:, 4])+np.min(tc2_2_84[:, 4])
            ,np.max(tc2_2_85[:, 4])+np.min(tc2_2_85[:, 4])]
plt.plot(Aspn1, FmaxHR2, 'o-', label=RH[1], color='orchid')
FmaxHR3 = [np.max(tc2_3_65[:, 4])+np.min(tc2_3_65[:, 4]),np.max(tc2_3_66[:, 4])+np.min(tc2_3_66[:, 4]),np.max(tc2_3_67[:, 4])+np.min(tc2_3_67[:, 4]),np.max(tc2_3_68[:, 4])+np.min(tc2_3_68[:, 4])
            ,np.max(tc2_3_69[:, 4])+np.min(tc2_3_69[:, 4]),np.max(tc2_3_70[:, 4])+np.min(tc2_3_70[:, 4]),np.max(tc2_3_71[:, 4])+np.min(tc2_3_71[:, 4]),np.max(tc2_3_72[:, 4])+np.min(tc2_3_72[:, 4])
            ,np.max(tc2_3_73[:, 4])+np.min(tc2_3_73[:, 4]),np.max(tc2_3_74[:, 4])+np.min(tc2_3_74[:, 4]),np.max(tc2_3_75[:, 4])+np.min(tc2_3_75[:, 4]),np.max(tc2_3_76[:, 4])+np.min(tc2_3_76[:, 4])
            ,np.max(tc2_3_77[:, 4])+np.min(tc2_3_77[:, 4]),np.max(tc2_3_78[:, 4])+np.min(tc2_3_78[:, 4]),np.max(tc2_3_79[:, 4])+np.min(tc2_3_79[:, 4]),np.max(tc2_3_80[:, 4])+np.min(tc2_3_80[:, 4])
            ,np.max(tc2_3_81[:, 4])+np.min(tc2_3_81[:, 4]),np.max(tc2_3_82[:, 4])+np.min(tc2_3_82[:, 4]),np.max(tc2_3_83[:, 4])+np.min(tc2_3_83[:, 4]),np.max(tc2_3_84[:, 4])+np.min(tc2_3_84[:, 4])
            ,np.max(tc2_3_85[:, 4])+np.min(tc2_3_85[:, 4])]
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.plot(Aspn1, FmaxHR3, 'o-', label=RH[2], color='blue')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.13, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/delta_PickF_c1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
Fstoc1_1_85,Fdisc1_1_85,Fproc1_1_85=FsFd(zc1_1_85,Es[0],Asp[4])
Fstoc1_1_80,Fdisc1_1_80,Fproc1_1_80=FsFd(zc1_1_80,Es[0],Asp[3])
Fstoc1_1_75,Fdisc1_1_75,Fproc1_1_75=FsFd(zc1_1_75,Es[0],Asp[2])
Fstoc1_1_70,Fdisc1_1_70,Fproc1_1_70=FsFd(zc1_1_70,Es[0],Asp[1])
Fstoc1_1_65,Fdisc1_1_65,Fproc1_1_65=FsFd(zc1_1_65,Es[0],Asp[0])
Fstoc1_2_85,Fdisc1_2_85,Fproc1_2_85=FsFd(zc1_2_85,Es[1],Asp[4])
Fstoc1_2_80,Fdisc1_2_80,Fproc1_2_80=FsFd(zc1_2_80,Es[1],Asp[3])
Fstoc1_2_75,Fdisc1_2_75,Fproc1_2_75=FsFd(zc1_2_75,Es[1],Asp[2])
Fstoc1_2_70,Fdisc1_2_70,Fproc1_2_70=FsFd(zc1_2_70,Es[1],Asp[1])
Fstoc1_2_65,Fdisc1_2_65,Fproc1_2_65=FsFd(zc1_2_65,Es[1],Asp[0])
Fstoc1_3_85,Fdisc1_3_85,Fproc1_3_85=FsFd(zc1_3_85,Es[2],Asp[4])
Fstoc1_3_80,Fdisc1_3_80,Fproc1_3_80=FsFd(zc1_3_80,Es[2],Asp[3])
Fstoc1_3_75,Fdisc1_3_75,Fproc1_3_75=FsFd(zc1_3_75,Es[2],Asp[2])
Fstoc1_3_70,Fdisc1_3_70,Fproc1_3_70=FsFd(zc1_3_70,Es[2],Asp[1])
Fstoc1_3_65,Fdisc1_3_65,Fproc1_3_65=FsFd(zc1_3_65,Es[2],Asp[0])
Fstoc2_1_85,Fdisc2_1_85,Fproc2_1_85=FsFd(zc2_1_85,Es[3],Asp[4])
Fstoc2_1_80,Fdisc2_1_80,Fproc2_1_80=FsFd(zc2_1_80,Es[3],Asp[3])
Fstoc2_1_75,Fdisc2_1_75,Fproc2_1_75=FsFd(zc2_1_75,Es[3],Asp[2])
Fstoc2_1_70,Fdisc2_1_70,Fproc2_1_70=FsFd(zc2_1_70,Es[3],Asp[1])
Fstoc2_1_65,Fdisc2_1_65,Fproc2_1_65=FsFd(zc2_1_65,Es[3],Asp[0])
Fstoc2_2_85,Fdisc2_2_85,Fproc2_2_85=FsFd(zc2_2_85,Es[4],Asp[4])
Fstoc2_2_80,Fdisc2_2_80,Fproc2_2_80=FsFd(zc2_2_80,Es[4],Asp[3])
Fstoc2_2_75,Fdisc2_2_75,Fproc2_2_75=FsFd(zc2_2_75,Es[4],Asp[2])
Fstoc2_2_70,Fdisc2_2_70,Fproc2_2_70=FsFd(zc2_2_70,Es[4],Asp[1])
Fstoc2_2_65,Fdisc2_2_65,Fproc2_2_65=FsFd(zc2_2_65,Es[4],Asp[0])
Fstoc2_3_85,Fdisc2_3_85,Fproc2_3_85=FsFd(zc2_3_85,Es[5],Asp[4])
Fstoc2_3_80,Fdisc2_3_80,Fproc2_3_80=FsFd(zc2_3_80,Es[5],Asp[3])
Fstoc2_3_75,Fdisc2_3_75,Fproc2_3_75=FsFd(zc2_3_75,Es[5],Asp[2])
Fstoc2_3_70,Fdisc2_3_70,Fproc2_3_70=FsFd(zc2_3_70,Es[5],Asp[1])
Fstoc2_3_65,Fdisc2_3_65,Fproc2_3_65=FsFd(zc2_3_65,Es[5],Asp[0])

# %%
Fproc2_1_80_aux=Fproc2_1_80
mask = (Fproc2_1_80_aux > 0) & (0.04 < t) & (t < 0.12)
Fproc2_1_80_aux[~mask] = 0
mask_pos = Fproc2_1_80_aux > 0
mask_neg1 = (Fproc2_1_80_aux == 0) & (t < 0.065)
mask_neg2 = (Fproc2_1_80_aux == 0) & (t > 0.095)
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)
ax3=fig.add_subplot(111, label="3", frame_on=False)
ax.set_xticks([])
ax.set_yticks([])
ax.plot(t[mask_pos]-0.021, Fproc2_1_80[mask_pos], color="#808080",linewidth=2.3,label='Tip$_t$')
ax.plot(t[mask_pos]-0.021, Fproc2_1_80[mask_pos], color="red",linewidth=2.3,label='Sim. [23]')
ax.plot(t[mask_pos]-0.021, Fproc2_1_80[mask_pos], color="tab:green",linewidth=2.5,label='Eq. 3')
ax.plot(t[mask_neg1]-0.021, Fproc2_1_80[mask_neg1], color="tab:green",linewidth=2.5, linestyle='--')
ax.plot(t[mask_neg2]-0.021, Fproc2_1_80[mask_neg2], color="tab:green",linewidth=2.5, linestyle='--')
ax.set_ylim(-1.1,1.7)
ax.set_xlim(0,0.131)
ax.plot()
ax2.set_xticks([])
ax2.set_yticks([])
ax2.tick_params(axis = 'y', labelsize = 18)
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()
ax2.locator_params(axis='y', nbins=6)
ax2.plot(tc2_1_80, tc2_1_80[:,5], color="#808080",linewidth=2.3)
ax2.set_xlim(998.45,998.9)
ax2.set_ylim(-11,17)
ax3.plot(tc2_1_80, tc2_1_65[:,4], color="red",linewidth=1.5, linestyle='--')
ax3.plot(tc2_1_80, tc2_1_70[:,4], color="red",linewidth=1.5, linestyle='--')
ax3.plot(tc2_1_80, tc2_1_75[:,4], color="red",linewidth=1.5, linestyle='--')
ax3.plot(tc2_1_80, tc2_1_80[:,4], color="red",linewidth=2.5)
ax3.plot(tc2_1_80, tc2_1_85[:,4], color="red",linewidth=1.5, linestyle='--')
ax3.set_xlim(998.45,998.9)
ax3.set_ylim(-1.1,1.7)
ax3.set_ylabel('$Force \; [nN]$', weight='bold', size=20)
ax3.set_xlabel('$t/T$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=6)
plt.text(998.46, 1.4, '$RH_1$', fontsize=20, color='red')
plt.text(998.67, -0.95, '$t_c$', fontsize=20, color='black')
ax.legend(fontsize=18, bbox_to_anchor=(0, 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/RH1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
Fproc2_2_80_aux=Fproc2_2_80
mask = (Fproc2_2_80_aux > 0) & (0.04 < t) & (t < 0.12)
Fproc2_2_80_aux[~mask] = 0
mask_pos = Fproc2_2_80_aux > 0
mask_neg1 = (Fproc2_2_80_aux == 0) & (t < 0.065)
mask_neg2 = (Fproc2_2_80_aux == 0) & (t > 0.095)
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)
ax3=fig.add_subplot(111, label="3", frame_on=False)
ax.set_xticks([])
ax.set_yticks([])
ax.plot(t[mask_pos]-0.021, Fproc2_2_80[mask_pos], color="#808080",linewidth=2.3,label='Tip$_t$')
ax.plot(t[mask_pos]-0.021, Fproc2_2_80[mask_pos], color="orchid",linewidth=2.3,label='Sim. [23]')
ax.plot(t[mask_pos]-0.021, Fproc2_2_80[mask_pos], color="tab:green",linewidth=2.5,label='Eq. 3')
ax.plot(t[mask_neg1]-0.021, Fproc2_2_80[mask_neg1], color="tab:green",linewidth=2.5, linestyle='--')
ax.plot(t[mask_neg2]-0.021, Fproc2_2_80[mask_neg2], color="tab:green",linewidth=2.5, linestyle='--')
ax.set_ylim(-1.1,1.7)
ax.set_xlim(0,0.1305)
ax.plot()
ax2.set_xticks([])
ax2.set_yticks([])
ax2.tick_params(axis = 'y', labelsize = 18)
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()
ax2.locator_params(axis='y', nbins=6)
ax2.plot(tc2_1_80, tc2_1_80[:,5], color="#808080",linewidth=1.5)
ax2.set_xlim(998.45,998.9)
ax2.set_ylim(-11,17)
ax3.plot(tc2_2_80, tc2_2_65[:,4], color="orchid",linewidth=1.5, linestyle='--')
ax3.plot(tc2_2_80, tc2_2_70[:,4], color="orchid",linewidth=1.5, linestyle='--')
ax3.plot(tc2_2_80, tc2_2_75[:,4], color="orchid",linewidth=1.5, linestyle='--')
ax3.plot(tc2_2_80, tc2_2_80[:,4], color="orchid",linewidth=2.5)
ax3.plot(tc2_2_80, tc2_2_85[:,4], color="orchid",linewidth=1.5, linestyle='--')
ax3.set_xlim(998.45,998.9)
ax3.set_ylim(-1.1,1.7)
ax3.set_ylabel('$Force \; [nN]$', weight='bold', size=20)
ax3.set_xlabel('$t/T$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=6)
plt.text(998.46, 1.4, '$RH_2$', fontsize=20, color='orchid')
plt.text(998.67, -0.95, '$t_c$', fontsize=20, color='black')
ax.legend(fontsize=18, bbox_to_anchor=(0, 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/RH2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
Fproc2_3_80_aux=Fproc2_3_80
mask = (Fproc2_3_80_aux > 0) & (0.04 < t) & (t < 0.12)
Fproc2_3_80_aux[~mask] = 0
mask_pos = Fproc2_3_80_aux > 0
mask_neg1 = (Fproc2_3_80_aux == 0) & (t < 0.07)
mask_neg2 = (Fproc2_3_80_aux == 0) & (t > 0.095)
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)
ax3=fig.add_subplot(111, label="3", frame_on=False)
ax.set_xticks([])
ax.set_yticks([])
ax.plot(t[mask_pos]-0.021, Fproc2_3_80[mask_pos], color="#808080",linewidth=2.3,label='Tip$_t$')
ax.plot(t[mask_pos]-0.021, Fproc2_3_80[mask_pos], color="blue",linewidth=2.3,label='Sim. [23]')
ax.plot(t[mask_pos]-0.021, Fproc2_3_80[mask_pos], color="tab:green",linewidth=2.5,label='Eq. 3')
ax.plot(t[mask_neg1]-0.021, Fproc2_3_80[mask_neg1], color="tab:green",linewidth=2.5, linestyle='--')
ax.plot(t[mask_neg2]-0.021, Fproc2_3_80[mask_neg2], color="tab:green",linewidth=2.5, linestyle='--')
ax.set_ylim(-1.1,1.7)
ax.set_xlim(0,0.131)
ax.plot()
ax2.set_xticks([])
ax2.set_yticks([])
ax2.tick_params(axis = 'y', labelsize = 18)
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()
ax2.locator_params(axis='y', nbins=6)
ax2.plot(tc2_1_80, tc2_1_80[:,5], color="#808080",linewidth=1.5)
ax2.set_xlim(998.45,998.9)
ax2.set_ylim(-11,17)
ax3.plot(tc2_3_80, tc2_3_65[:,4], color="blue",linewidth=1.5, linestyle='--')
ax3.plot(tc2_3_80, tc2_3_70[:,4], color="blue",linewidth=1.5, linestyle='--')
ax3.plot(tc2_3_80, tc2_3_75[:,4], color="blue",linewidth=1.5, linestyle='--')
ax3.plot(tc2_3_80, tc2_3_80[:,4], color="blue",linewidth=2.5)
ax3.plot(tc2_3_80, tc2_3_85[:,4], color="blue",linewidth=1.5, linestyle='--')
ax3.set_xlim(998.45,998.9)
ax3.set_ylim(-1.1,1.7)
ax3.set_ylabel('$Force \; [nN]$', weight='bold', size=20)
ax3.set_xlabel('$t/T$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=6)
plt.text(998.46, 1.4, '$RH_3$', fontsize=20, color='blue')
plt.text(998.67, -0.95, '$t_c$', fontsize=20, color='black')
ax.legend(fontsize=18, bbox_to_anchor=(0, 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/RH3.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$\phi \; [\degree]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
zc1 = []
am1 = []
fa1 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_1_80[:, 1] == zc2_1_80[:, 1].flat[np.abs(
        zc2_1_80[:, 1] - Asp1[j]).argmin()])
    zc1.append(zc2_1_80[:, 0][aux1])
    am1.append(zc2_1_80[:, 1][aux1])
    fa1.append(zc2_1_80[:, 2][aux1])
plt.plot(Aspn1,fa1, 'o-', label=RH[0], color='red')
zc2 = []
am2 = []
fa2 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_2_80[:, 1] == zc2_2_80[:, 1].flat[np.abs(
        zc2_2_80[:, 1] - Asp1[j]).argmin()])
    zc2.append(zc2_2_80[:, 0][aux1])
    am2.append(zc2_2_80[:, 1][aux1])
    fa2.append(zc2_2_80[:, 2][aux1])    
plt.plot(Aspn1,fa2, 'o-', label=RH[1], color='orchid')
zc3 = []
am3 = []
fa3 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_3_80[:, 1] == zc2_3_80[:, 1].flat[np.abs(
        zc2_3_80[:, 1] - Asp1[j]).argmin()])
    zc3.append(zc2_3_80[:, 0][aux1])
    am3.append(zc2_3_80[:, 1][aux1])
    fa3.append(zc2_3_80[:, 2][aux1])    
plt.plot(Aspn1,fa3, 'o-', label=RH[2], color='blue') 
plt.locator_params(axis='x', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/fasec1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$\phi \; [\degree]$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
zc1 = []
am1 = []
fa1 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_1_80[:, 1] == zc1_1_80[:, 1].flat[np.abs(
        zc1_1_80[:, 1] - Asp1[j]).argmin()])
    zc1.append(zc1_1_80[:, 0][aux1])
    am1.append(zc1_1_80[:, 1][aux1])
    fa1.append(zc1_1_80[:, 2][aux1])
plt.plot(Aspn1,fa1, 'o-', label=RH[0], color='red')
zc2 = []
am2 = []
fa2 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_2_80[:, 1] == zc1_2_80[:, 1].flat[np.abs(
        zc1_2_80[:, 1] - Asp1[j]).argmin()])
    zc2.append(zc1_2_80[:, 0][aux1])
    am2.append(zc1_2_80[:, 1][aux1])
    fa2.append(zc1_2_80[:, 2][aux1])    
plt.plot(Aspn1,fa2, 'o-', label=RH[1], color='orchid')
zc3 = []
am3 = []
fa3 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_3_80[:, 1] == zc1_3_80[:, 1].flat[np.abs(
        zc1_3_80[:, 1] - Asp1[j]).argmin()])
    zc3.append(zc1_3_80[:, 0][aux1])
    am3.append(zc1_3_80[:, 1][aux1])
    fa3.append(zc1_3_80[:, 2][aux1])    
plt.plot(Aspn1,fa3, 'o-', label=RH[2], color='blue') 
plt.locator_params(axis='x', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.3, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/fasec2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
a0=0.165
plt.figure()
plt.ylabel('$\delta_{max} \: [nm]$', weight='bold', size=21)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=21)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
zc1 = []
am1 = []
zt1 = []
si1 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_1_80[:, 1] == zc1_1_80[:, 1].flat[np.abs(
        zc1_1_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc1_1_80[:, 3][aux1])
    zc1.append(zc1_1_80[:, 0][aux1])
    am1.append(zc1_1_80[:, 1][aux1])
    zt1.append(zc1_1_80[:, 3][aux1])
    si1.append(sigaux)
plt.plot(Aspn1,si1, 'o-', label=RH[0], color='red')
zc2 = []
am2 = []
zt2 = []
si2 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_2_80[:, 1] == zc1_2_80[:, 1].flat[np.abs(
        zc1_2_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc1_2_80[:, 3][aux1])
    zc2.append(zc1_2_80[:, 0][aux1])
    am2.append(zc1_2_80[:, 1][aux1])
    zt2.append(zc1_2_80[:, 3][aux1])
    si2.append(sigaux)
plt.plot(Aspn1,si2, 'o-', label=RH[1], color='orchid')
zc3 = []
am3 = []
zt3 = []
si3 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc1_3_80[:, 1] == zc1_3_80[:, 1].flat[np.abs(
        zc1_3_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc1_3_80[:, 3][aux1])
    zc3.append(zc1_3_80[:, 0][aux1])
    am3.append(zc1_3_80[:, 1][aux1])
    zt3.append(zc1_3_80[:, 3][aux1])
    si3.append(sigaux)
plt.plot(Aspn1,si3, 'o-', label=RH[2], color='blue')
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/sigma_max_c2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$\delta_{max} \: [nm]$', weight='bold', size=21)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=21)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
zc1 = []
am1 = []
zt1 = []
si1 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_1_80[:, 1] == zc2_1_80[:, 1].flat[np.abs(
        zc2_1_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc2_1_80[:, 3][aux1])
    zc1.append(zc2_1_80[:, 0][aux1])
    am1.append(zc2_1_80[:, 1][aux1])
    zt1.append(zc2_1_80[:, 3][aux1])
    si1.append(sigaux)
plt.plot(Aspn1,si1, 'o-', label=RH[0], color='red')
zc2 = []
am2 = []
zt2 = []
si2 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_2_80[:, 1] == zc2_2_80[:, 1].flat[np.abs(
        zc2_2_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc2_2_80[:, 3][aux1])
    zc2.append(zc2_2_80[:, 0][aux1])
    am2.append(zc2_2_80[:, 1][aux1])
    zt2.append(zc2_2_80[:, 3][aux1])
    si2.append(sigaux)
plt.plot(Aspn1,si2, 'o-', label=RH[1], color='orchid')
zc3 = []
am3 = []
zt3 = []
si3 = []
for j in range(len(Asp1)):
    aux1 = np.where(zc2_3_80[:, 1] == zc2_3_80[:, 1].flat[np.abs(
        zc2_3_80[:, 1] - Asp1[j]).argmin()])
    sigaux = a0-(zc2_3_80[:, 3][aux1])
    zc3.append(zc2_3_80[:, 0][aux1])
    am3.append(zc2_3_80[:, 1][aux1])
    zt3.append(zc2_3_80[:, 3][aux1])
    si3.append(sigaux)
plt.plot(Aspn1,si3, 'o-', label=RH[2], color='blue')
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/sigma_max_c1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
def tcT (tc1_1_65):
    dfFT1HR1 = pd.DataFrame(tc1_1_65, columns = ['t/T','pos','vel','zc','force','dist','vdw','hertz','visco','cap','LJ','dlvo'])
    df1 = dfFT1HR1[dfFT1HR1['t/T'] >= 999]
    cdf2 = df1[df1['force'] <-0.01]
    aux1=cdf2['t/T'].max()
    aux2=cdf2['t/T'].min()
    tc = aux1-aux2 
    df3 = dfFT1HR1[dfFT1HR1['t/T'] >= 998]
    cdf3 = df3[df3['force'] <-0.01]
    cdf4 = cdf3[cdf3['t/T'] <=aux2]
    aux3=cdf4['t/T'].max()
    aux4=cdf4['t/T'].min()
    T = aux3-aux4 
    tc_T= tc/T
    return tc_T

# %%
asp65HR1c1=tcT(tc1_1_65);asp66HR1c1=tcT(tc1_1_66);asp67HR1c1=tcT(tc1_1_67);asp68HR1c1=tcT(tc1_1_68);asp69HR1c1=tcT(tc1_1_69);asp70HR1c1=tcT(tc1_1_70)
asp71HR1c1=tcT(tc1_1_71);asp72HR1c1=tcT(tc1_1_72);asp73HR1c1=tcT(tc1_1_73);asp74HR1c1=tcT(tc1_1_74);asp75HR1c1=tcT(tc1_1_75);asp76HR1c1=tcT(tc1_1_76)
asp77HR1c1=tcT(tc1_1_77);asp78HR1c1=tcT(tc1_1_78);asp79HR1c1=tcT(tc1_1_79);asp80HR1c1=tcT(tc1_1_80);asp81HR1c1=tcT(tc1_1_81);asp82HR1c1=tcT(tc1_1_82)
asp83HR1c1=tcT(tc1_1_83);asp84HR1c1=tcT(tc1_1_84);asp85HR1c1=tcT(tc1_1_85)
tcHR1c1= np.array([asp65HR1c1,asp66HR1c1,asp67HR1c1,asp68HR1c1,asp69HR1c1,asp70HR1c1,asp71HR1c1,asp72HR1c1,asp73HR1c1,asp74HR1c1,asp75HR1c1,asp76HR1c1,asp77HR1c1
                   ,asp78HR1c1,asp79HR1c1,asp80HR1c1,asp81HR1c1,asp82HR1c1,asp83HR1c1,asp84HR1c1,asp85HR1c1])
asp65HR2c1=tcT(tc1_2_65);asp66HR2c1=tcT(tc1_2_66);asp67HR2c1=tcT(tc1_2_67);asp68HR2c1=tcT(tc1_2_68);asp69HR2c1=tcT(tc1_2_69);asp70HR2c1=tcT(tc1_2_70)
asp71HR2c1=tcT(tc1_2_71);asp72HR2c1=tcT(tc1_2_72);asp73HR2c1=tcT(tc1_2_73);asp74HR2c1=tcT(tc1_2_74);asp75HR2c1=tcT(tc1_2_75);asp76HR2c1=tcT(tc1_2_76)
asp77HR2c1=tcT(tc1_2_77);asp78HR2c1=tcT(tc1_2_78);asp79HR2c1=tcT(tc1_2_79);asp80HR2c1=tcT(tc1_2_80);asp81HR2c1=tcT(tc1_2_81);asp82HR2c1=tcT(tc1_2_82)
asp83HR2c1=tcT(tc1_2_83);asp84HR2c1=tcT(tc1_2_84);asp85HR2c1=tcT(tc1_2_85)
tcHR2c1= np.array([asp65HR2c1,asp66HR2c1,asp67HR2c1,asp68HR2c1,asp69HR2c1,asp70HR2c1,asp71HR2c1,asp72HR2c1,asp73HR2c1,asp74HR2c1,asp75HR2c1,asp76HR2c1,asp77HR2c1
                   ,asp78HR2c1,asp79HR2c1,asp80HR2c1,asp81HR2c1,asp82HR2c1,asp83HR2c1,asp84HR2c1,asp85HR2c1])
asp65HR3c1=tcT(tc1_3_65);asp66HR3c1=tcT(tc1_3_66);asp67HR3c1=tcT(tc1_3_67);asp68HR3c1=tcT(tc1_3_68);asp69HR3c1=tcT(tc1_3_69);asp70HR3c1=tcT(tc1_3_70)
asp71HR3c1=tcT(tc1_3_71);asp72HR3c1=tcT(tc1_3_72);asp73HR3c1=tcT(tc1_3_73);asp74HR3c1=tcT(tc1_3_74);asp75HR3c1=tcT(tc1_3_75);asp76HR3c1=tcT(tc1_3_76)
asp77HR3c1=tcT(tc1_3_77);asp78HR3c1=tcT(tc1_3_78);asp79HR3c1=tcT(tc1_3_79);asp80HR3c1=tcT(tc1_3_80);asp81HR3c1=tcT(tc1_3_81);asp82HR3c1=tcT(tc1_3_82)
asp83HR3c1=tcT(tc1_3_83);asp84HR3c1=tcT(tc1_3_84);asp85HR3c1=tcT(tc1_3_85)
tcHR3c1= np.array([asp65HR3c1,asp66HR3c1,asp67HR3c1,asp68HR3c1,asp69HR3c1,asp70HR3c1,asp71HR3c1,asp72HR3c1,asp73HR3c1,asp74HR3c1,asp75HR3c1,asp76HR3c1,asp77HR3c1
                   ,asp78HR3c1,asp79HR3c1,asp80HR3c1,asp81HR3c1,asp82HR3c1,asp83HR3c1,asp84HR3c1,asp85HR3c1])
asp65HR1c2=tcT(tc2_1_65);asp66HR1c2=tcT(tc2_1_66);asp67HR1c2=tcT(tc2_1_67);asp68HR1c2=tcT(tc2_1_68);asp69HR1c2=tcT(tc2_1_69);asp70HR1c2=tcT(tc2_1_70)
asp71HR1c2=tcT(tc2_1_71);asp72HR1c2=tcT(tc2_1_72);asp73HR1c2=tcT(tc2_1_73);asp74HR1c2=tcT(tc2_1_74);asp75HR1c2=tcT(tc2_1_75);asp76HR1c2=tcT(tc2_1_76)
asp77HR1c2=tcT(tc2_1_77);asp78HR1c2=tcT(tc2_1_78);asp79HR1c2=tcT(tc2_1_79);asp80HR1c2=tcT(tc2_1_80);asp81HR1c2=tcT(tc2_1_81);asp82HR1c2=tcT(tc2_1_82)
asp83HR1c2=tcT(tc2_1_83);asp84HR1c2=tcT(tc2_1_84);asp85HR1c2=tcT(tc2_1_85)
tcHR1c2= np.array([asp65HR1c2,asp66HR1c2,asp67HR1c2,asp68HR1c2,asp69HR1c2,asp70HR1c2,asp71HR1c2,asp72HR1c2,asp73HR1c2,asp74HR1c2,asp75HR1c2,asp76HR1c2,asp77HR1c2
                   ,asp78HR1c2,asp79HR1c2,asp80HR1c2,asp81HR1c2,asp82HR1c2,asp83HR1c2,asp84HR1c2,asp85HR1c2])
asp65HR2c2=tcT(tc2_2_65);asp66HR2c2=tcT(tc2_2_66);asp67HR2c2=tcT(tc2_2_67);asp68HR2c2=tcT(tc2_2_68);asp69HR2c2=tcT(tc2_2_69);asp70HR2c2=tcT(tc2_2_70)
asp71HR2c2=tcT(tc2_2_71);asp72HR2c2=tcT(tc2_2_72);asp73HR2c2=tcT(tc2_2_73);asp74HR2c2=tcT(tc2_2_74);asp75HR2c2=tcT(tc2_2_75);asp76HR2c2=tcT(tc2_2_76)
asp77HR2c2=tcT(tc2_2_77);asp78HR2c2=tcT(tc2_2_78);asp79HR2c2=tcT(tc2_2_79);asp80HR2c2=tcT(tc2_2_80);asp81HR2c2=tcT(tc2_2_81);asp82HR2c2=tcT(tc2_2_82)
asp83HR2c2=tcT(tc2_2_83);asp84HR2c2=tcT(tc2_2_84);asp85HR2c2=tcT(tc2_2_85)
tcHR2c2= np.array([asp65HR2c2,asp66HR2c2,asp67HR2c2,asp68HR2c2,asp69HR2c2,asp70HR2c2,asp71HR2c2,asp72HR2c2,asp73HR2c2,asp74HR2c2,asp75HR2c2,asp76HR2c2,asp77HR2c2
                   ,asp78HR2c2,asp79HR2c2,asp80HR2c2,asp81HR2c2,asp82HR2c2,asp83HR2c2,asp84HR2c2,asp85HR2c2])
asp65HR3c2=tcT(tc2_3_65);asp66HR3c2=tcT(tc2_3_66);asp67HR3c2=tcT(tc2_3_67);asp68HR3c2=tcT(tc2_3_68);asp69HR3c2=tcT(tc2_3_69);asp70HR3c2=tcT(tc2_3_70)
asp71HR3c2=tcT(tc2_3_71);asp72HR3c2=tcT(tc2_3_72);asp73HR3c2=tcT(tc2_3_73);asp74HR3c2=tcT(tc2_3_74);asp75HR3c2=tcT(tc2_3_75);asp76HR3c2=tcT(tc2_3_76)
asp77HR3c2=tcT(tc2_3_77);asp78HR3c2=tcT(tc2_3_78);asp79HR3c2=tcT(tc2_3_79);asp80HR3c2=tcT(tc2_3_80);asp81HR3c2=tcT(tc2_3_81);asp82HR3c2=tcT(tc2_3_82)
asp83HR3c2=tcT(tc2_3_83);asp84HR3c2=tcT(tc2_3_84);asp85HR3c2=tcT(tc2_3_85)
tcHR3c2= np.array([asp65HR3c2,asp66HR3c2,asp67HR3c2,asp68HR3c2,asp69HR3c2,asp70HR3c2,asp71HR3c2,asp72HR3c2,asp73HR3c2,asp74HR3c2,asp75HR3c2,asp76HR3c2,asp77HR3c2
                   ,asp78HR3c2,asp79HR3c2,asp80HR3c2,asp81HR3c2,asp82HR3c2,asp83HR3c2,asp84HR3c2,asp85HR3c2])

# %%
plt.figure()
plt.ylabel('$t_{c} \; /T$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(Aspn1, tcHR1c1, 'o-', label=RH[0], color='red')
plt.plot(Aspn1, tcHR2c1, 'o-', label=RH[1], color='orchid')
plt.plot(Aspn1, tcHR3c1, 'o-', label=RH[2], color='blue')
plt.locator_params(axis='x', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/tc_c2.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$t_{c} \; /T$', weight='bold', size=20)
plt.xlabel('$A_{sp}/A_0$', weight='bold', size=20)
parameters = {'legend.fontsize': 18}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(Aspn1, tcHR1c2, 'o-', label=RH[0], color='red')
plt.plot(Aspn1, tcHR2c2, 'o-', label=RH[1], color='orchid')
plt.plot(Aspn1, tcHR3c2, 'o-', label=RH[2], color='blue')
plt.locator_params(axis='x', nbins=5)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
plt.text(0.88, 0.8, "Model 1", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/tc_c1.png', bbox_inches='tight',dpi=400)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 14.5}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 6], color='#FF9AA2', marker = "v",markevery=15 ,linewidth=2, label='$F_{vdw}$')
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 7], color='#C8B8A1', marker = 's',markevery=15 , linewidth=2, label='$F_{hertz}$')
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 8], color='#A29FC3', marker = '8',markevery=15 , linewidth=2, label='$F_{visco}$')
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 9], color='#B5EAD7', marker = '<',markevery=15 , linewidth=2, label='$F_{cap}$')
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 11], color='#FFDAC1', marker = '>',markevery=15 , linewidth=2, label='$F_{dl}$')
plt.plot(tc1_1_80[:, 0], tc1_1_80[:, 4], color='red', ls = '--', linewidth=3.0, label='$F_{total}$')
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=6)
plt.legend(loc='upper right')
plt.text(0.3, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/fig_interHR1C2.png', bbox_inches='tight',dpi=800)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 14.5}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 6], color='#FF9AA2', marker = "v",markevery=15 ,linewidth=2, label='$F_{vdw}$')
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 7], color='#C8B8A1', marker = 's',markevery=15 , linewidth=2, label='$F_{hertz}$')
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 8], color='#A29FC3', marker = '8',markevery=15 , linewidth=2, label='$F_{visco}$')
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 9], color='#B5EAD7', marker = '<',markevery=15 , linewidth=2, label='$F_{cap}$')
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 11], color='#FFDAC1', marker = '>',markevery=15 , linewidth=2, label='$F_{dl}$')
plt.plot(tc1_2_80[:, 0], tc1_2_80[:, 4], color='orchid', ls = '--', linewidth=3.0, label='$F_{total}$')
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=6)
plt.legend(loc='upper right')
plt.text(0.3, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/fig_interHR2C2.png', bbox_inches='tight',dpi=800)
plt.show()

# %%
plt.figure()
plt.ylabel('$Force \; [nN]$', weight='bold', size=20)
plt.xlabel('$t/T$', weight='bold', size=20)
plt.xlim(999.5, 999.93)
parameters = {'legend.fontsize': 14.5}
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.rcParams.update(parameters)
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 6], color='#FF9AA2', marker = "v",markevery=15 ,linewidth=2, label='$F_{vdw}$')
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 7], color='#C8B8A1', marker = 's',markevery=15 , linewidth=2, label='$F_{hertz}$')
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 8], color='#A29FC3', marker = '8',markevery=15 , linewidth=2, label='$F_{visco}$')
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 9], color='#B5EAD7', marker = '<',markevery=15 , linewidth=2, label='$F_{cap}$')
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 11], color='#FFDAC1', marker = '>',markevery=15 , linewidth=2, label='$F_{dl}$')
plt.plot(tc1_3_80[:, 0], tc1_3_80[:, 4], color='blue', ls = '--', linewidth=3.0, label='$F_{total}$')
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.locator_params(axis='x', nbins=5)
plt.locator_params(axis='y', nbins=6)
plt.legend(loc='upper right')
plt.text(0.3, 0.8, "Model 2", transform=plt.gcf().transFigure, fontsize=18,ha='right', va='bottom')
plt.savefig('Figures/fig_interHR3C2.png', bbox_inches='tight',dpi=800)
plt.show()
